# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib
import geopandas as gpd

# %%
data = pd.read_csv(r"C:\Users\mekon\Desktop\pythondata...csv", low_memory=False)

# %%
data.head()
# Out:
#   MEMBER STATE  TOTAL RX AMOUNT1 Pharmacy State  Total Rx  Amount2  \
# 0           IN        5038560.80             TX         4616061.97
# 1           TN        4236163.58             IN         3489880.33
# 2           OH        1465984.46             TN         2575603.10
# 3           MN         942027.28             IL         1558305.37
# 4           IA         864788.93             IA         1292309.23
#
#   Prescriber State  Total Rx Amount3
# 0               IN        4718159.02
# 1               TN        4054741.51
# 2               OH        1471861.33
# 3               MN        1125989.09
# 4               TX         828084.50

# %%
data.describe()
# Out:
#        TOTAL RX AMOUNT1  Total Rx  Amount2  Total Rx Amount3
# count      5.100000e+01       5.200000e+01      5.200000e+01
# mean       4.017373e+05       3.962454e+05      3.957118e+05
# std        9.166844e+05       8.954790e+05      8.640102e+05
# min        1.185000e+02       8.300000e+00      1.611400e+02
# 25%        2.962052e+04       5.149952e+03      4.048807e+04
# 50%        1.153830e+05       3.070557e+04      1.318653e+05
# 75%        3.249810e+05       2.970676e+05      3.294824e+05
# max        5.038561e+06       4.616062e+06      4.718159e+06

# %%
data.columns
# Out:
# Index(['MEMBER STATE', 'TOTAL RX AMOUNT1', 'Pharmacy State',
#        'Total Rx  Amount2', 'Prescriber State', 'Total Rx Amount3'],
#       dtype='object')

# %%
data.head(10)
# Out:
#   MEMBER STATE  TOTAL RX AMOUNT1 Pharmacy State  Total Rx  Amount2  \
# 0           IN        5038560.80             TX         4616061.97
# 1           TN        4236163.58             IN         3489880.33
# 2           OH        1465984.46             TN         2575603.10
# 3           MN         942027.28             IL         1558305.37
# 4           IA         864788.93             IA         1292309.23
# 5           TX         736254.62             PA         1177492.61
# 6           FL         727940.87             NY         1090788.54
# 7           MD         621622.34             MI          861727.64
# 8           NC         593641.16             MO          661705.83
# 9           WI         461653.15             KS          603316.36
#
#   Prescriber State  Total Rx Amount3
# 0               IN        4718159.02
# 1               TN        4054741.51
# 2               OH        1471861.33
# 3               MN        1125989.09
# 4               TX         828084.50
# ...

# %%
x=["IN","TN", "OH", "MN","IA","TX","FL","MD","NC","WI"]
h=[5.4,4.2,1.5,0.90,0.86,0.74,0.73,0.62,0.60,0.46]
plt.bar(x,h,color="grey")
plt.ylabel("Total Rx Amount in millions($)")
plt.xlabel("Memebr State")
plt.title("The dollar value of prescriptions dispensed in January 2021 per Member state")
plt.show()

x=["IN","TN","OH", "MN", "TX", "IA", "FL","NC","IL","MD"] 
h=[4.7,4.1,1.5,1.1,0.8,0.75,0.72,0.67,0.58,0.56]
plt.bar(x,h,color="grey") 
plt.ylabel("Total Rx Amount in millions($)") 
plt.xlabel("Prescriber State") 
plt.title("The dollar value of prescriptions dispensed in January 2021 per Prescriber state") 
plt.show() 

x=["TX","IN","TN", "IL", "IA", "PA", "NY","MI","MO","KS"] 
h=[4.6,3.5,2.6,1.6,1.3,1.2,1.1,0.9,0.7,0.6]
plt.bar(x,h,color="grey") 
plt.ylabel("Total Rx Amount in millions($)") 
plt.xlabel("Pharmacy State") 
plt.title("The dollar value of prescriptions dispensed in January 2021 per Pharmacy state") 
plt.show()
