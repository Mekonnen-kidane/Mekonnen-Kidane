# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\mekon\Desktop\immigData.xlsx")

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#                    country    TOTAL  year2020  year2019  year2018  year2017  \
# 0                   Mexico  1480901    100325    156052    161858    170581
# 1                    China   713527     41483     62248     65214     71565
# 2                    India   631689     46363     54495     59821     60394
# 3              Philippines   496361     25491     45920     47258     49147
# 4       Dominican Republic   481183     30005     49911     57413     58520
# ..                     ...      ...       ...       ...       ...       ...
# 190                 Monaco       90         8         7        13        14
# 191             Seychelles       88         4         6         6        10
# 192  Sao Tome and Principe       85         4        12         9        10
# 193                Comoros       65         4        10         8         4
# 194               Maldives       64         4         8         4         5
#
# ...

# %%
df.rename(columns={'year2020':'2020', 'year2019':'2019','year2018':'2018','year2017':'2017', 'year2016':'2016',
                   'year2015':'2015','year2014':'2014', 'year2013':'2013','year2012':'2012','year2011':'2011'}, 
                    inplace=True)
df.head()
# Out:
#               country    TOTAL    2020    2019    2018    2017    2016  \
# 0              Mexico  1480901  100325  156052  161858  170581  174534
# 1               China   713527   41483   62248   65214   71565   81772
# 2               India   631689   46363   54495   59821   60394   64687
# 3         Philippines   496361   25491   45920   47258   49147   53287
# 4  Dominican Republic   481183   30005   49911   57413   58520   61161
#
#      2015    2014    2013    2012      2011      continnet
# 0  158619  134052  135028  146406  143446.0  North America
# 1   74558   76089   71798   81784   87016.0           Asia
# 2   64116   77908   68458   66434   69013.0           Asia
# 3   56478   49996   54446   57327   57011.0           Asia
# 4   50610   44577   41311   41566   46109.0      Caribbean

# %%
df.tail()
# Out:
#                    country  TOTAL  2020  2019  2018  2017  2016  2015  2014  \
# 190                 Monaco     90     8     7    13    14    11    10     8
# 191             Seychelles     88     4     6     6    10    16    11     7
# 192  Sao Tome and Principe     85     4    12     9    10    12     6     5
# 193                Comoros     65     4    10     8     4     4     5     9
# 194               Maldives     64     4     8     4     5    11     8    13
#
#      2013  2012  2011 continnet
# 190     8     5   6.0    Europe
# 191     6     7  15.0    Africa
# 192     6    12   9.0    Africa
# 193     3    10   8.0    Africa
# 194     5     3   3.0      Asia

# %%
df.columns
# Out:
# Index(['country', 'TOTAL', '2020', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', 'continnet'],
#       dtype='object')

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Columns: 13 entries, country to continnet
# dtypes: float64(1), int64(10), object(2)
# memory usage: 19.9+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
df.isnull().sum()
# Out:
# country      0
# TOTAL        0
# 2020         0
# 2019         0
# 2018         0
# 2017         0
# 2016         0
# 2015         0
# 2014         0
# 2013         0
# 2012         0
# 2011         1
# continnet    0
# dtype: int64

# %%
df.describe()
# Out:
#               TOTAL           2020           2019           2018  \
# count  1.950000e+02     195.000000     195.000000     195.000000
# mean   5.190117e+04    3586.364103    5234.097436    5552.446154
# std    1.422684e+05    9433.509031   14328.402487   15547.068156
# min    6.400000e+01       4.000000       6.000000       4.000000
# 25%    2.022000e+03     151.000000     228.000000     243.000000
# 50%    9.939000e+03     761.000000    1109.000000     960.000000
# 75%    4.105300e+04    2854.000000    3820.000000    3682.000000
# max    1.480901e+06  100325.000000  156052.000000  161858.000000
#
#                 2017           2016           2015           2014  \
# count     195.000000     195.000000     195.000000     195.000000
# mean     5679.241026    5966.635897    5300.092308    5129.282051
# std     15983.811817   16709.421621   15104.691536   13914.723250
# min         4.000000       4.000000       5.000000       5.000000
# ...

# %%
df.country
# Out:
# 0                     Mexico
# 1                      China
# 2                      India
# 3                Philippines
# 4         Dominican Republic
#                ...
# 190                   Monaco
# 191               Seychelles
# 192    Sao Tome and Principe
# 193                  Comoros
# 194                 Maldives
# Name: country, Length: 195, dtype: object

# %%
df.set_index('country', inplace=True)

# %%
df.head(3)
# Out:
#            TOTAL    2020    2019    2018    2017    2016    2015    2014  \
# country
# Mexico   1480901  100325  156052  161858  170581  174534  158619  134052
# China     713527   41483   62248   65214   71565   81772   74558   76089
# India     631689   46363   54495   59821   60394   64687   64116   77908
#
#            2013    2012      2011      continnet
# country
# Mexico   135028  146406  143446.0  North America
# China     71798   81784   87016.0           Asia
# India     68458   66434   69013.0           Asia

# %%
df[df.index == 'Eritrea']
# Out:
#          TOTAL  2020  2019  2018  2017  2016  2015  2014  2013  2012    2011  \
# country
# Eritrea  22515  1881  2385  2428  2449  2267  2220  2002  2138  2643  2102.0
#
#         continnet
# country
# Eritrea    Africa

# %%
df.loc['Eritrea']
# Out:
# TOTAL         22515
# 2020           1881
# 2019           2385
# 2018           2428
# 2017           2449
# 2016           2267
# 2015           2220
# 2014           2002
# 2013           2138
# 2012           2643
# 2011         2102.0
# continnet    Africa
# Name: Eritrea, dtype: object

# %%
df.columns = list(map(str, df.columns))

# %%
# useful for plotting later on
years = list(map(str, range(2011, 2021)))
years
# Out:
# ['2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
Eritrea = df.loc['Eritrea', years] 
Eritrea.head()
# Out:
# 2011    2102.0
# 2012      2643
# 2013      2138
# 2014      2002
# 2015      2220
# Name: Eritrea, dtype: object

# %% [markdown]
# # Line Plot
# Immigration from Eritrea

# %%
Eritrea.index = Eritrea.index.map(int) 
Eritrea.plot(kind='line')
plt.title('Immigration from Eritrea')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_EE= df.loc[['Eritrea', 'Ethiopia'], years]
df_EE
# Out:
#              2011   2012   2013   2014   2015   2016   2017   2018  2019  2020
# country
# Eritrea    2102.0   2643   2138   2002   2220   2267   2449   2428  2385  1881
# Ethiopia  13793.0  14544  13097  12300  11394  13232  14637  12403  9060  6280

# %%
df_EE = df_EE.transpose()
df_EE.head()
# Out:
# country  Eritrea  Ethiopia
# 2011      2102.0   13793.0
# 2012      2643.0   14544.0
# 2013      2138.0   13097.0
# 2014      2002.0   12300.0
# 2015      2220.0   11394.0

# %% [markdown]
# # Line Plot
# Immigration from Eritrea and Ethiopia

# %%
df_EE.index = df_EE.index.map(int)
df_EE.plot(kind='line')

plt.title('Immigration from Eritrea and Ethiopia')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# # Line Plot
# Immigration Trend of Top 5 Countries

# %%
inplace = True 
df.sort_values(by='TOTAL', ascending=False, axis=0, inplace=True)
df_top5 = df.head(5)
df_top5 = df_top5[years].transpose() 
print(df_top5)
# Out:
# country    Mexico    China    India  Philippines  Dominican Republic
# 2011     143446.0  87016.0  69013.0      57011.0             46109.0
# 2012     146406.0  81784.0  66434.0      57327.0             41566.0
# 2013     135028.0  71798.0  68458.0      54446.0             41311.0
# 2014     134052.0  76089.0  77908.0      49996.0             44577.0
# 2015     158619.0  74558.0  64116.0      56478.0             50610.0
# 2016     174534.0  81772.0  64687.0      53287.0             61161.0
# 2017     170581.0  71565.0  60394.0      49147.0             58520.0
# 2018     161858.0  65214.0  59821.0      47258.0             57413.0
# 2019     156052.0  62248.0  54495.0      45920.0             49911.0
# 2020     100325.0  41483.0  46363.0      25491.0             30005.0

# %%
df_top5.index = df_top5.index.map(int) 
df_top5.plot(kind='line', figsize=(14, 8)) 
plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# # Stacked Area Plot
# Immigration Trend of Top 5 Countries

# %%
df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='area',
             alpha=0.25, 
             stacked=False,
             figsize=(20, 10))

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# # Stacked Area Plot
# Immigration Trend of 5 Countries with Least Contribution to Immigration

# %%
df_least5 = df.tail(5)
df_least5 = df_least5[years].transpose() 
df_least5.head()

df_least5.index = df_least5.index.map(int) 
df_least5.plot(kind='area', alpha=0.45, figsize=(20, 10)) 

plt.title('Immigration Trend of 5 Countries with Least Contribution to Immigration')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# # Unstacked Area plot:
# Immigration Trend of 5 Countries with Least Contribution to Immigration

# %%
df_least5 = df.tail(5)

df_least5 = df_least5[years].transpose() 
df_least5.head()

df_least5.index = df_least5.index.map(int) 
ax = df_least5.plot(kind='area', alpha=0.55, stacked=False, figsize=(20, 10))
    
ax.set_title('Immigration Trend of 5 Countries with Least Contribution to Immigration')
ax.set_ylabel('Number of Immigrants')
ax.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# # Histogram
# Immigration from 195 Countries in 2020

# %%
df['2020'].head()
# Out:
# country
# Mexico                100325
# China                  41483
# India                  46363
# Philippines            25491
# Dominican Republic     30005
# Name: 2020, dtype: int64

# %%
count, bin_edges = np.histogram(df['2020'])

print(count)
print(bin_edges)
# Out:
# [179  10   3   0   2   0   0   0   0   1]
# [4.00000e+00 1.00361e+04 2.00682e+04 3.01003e+04 4.01324e+04 5.01645e+04
#  6.01966e+04 7.02287e+04 8.02608e+04 9.02929e+04 1.00325e+05]

# %%
count, bin_edges = np.histogram(df['2020'])
df['2020'].plot(kind='hist', figsize=(8, 5),xticks=bin_edges)

plt.title('Immigration from 195 Countries in 2020')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# # Histogram
# Immigration from East Africa from 2011 - 2020

# %%
df.loc[['Eritrea', 'Ethiopia', 'Sudan','Somalia','Kenya','Uganda','Rwanda','Tanzania','Djibouti'], years]
# Out:
#              2011   2012   2013   2014   2015   2016   2017   2018  2019  2020
# country
# Eritrea    2102.0   2643   2138   2002   2220   2267   2449   2428  2385  1881
# Ethiopia  13793.0  14544  13097  12300  11394  13232  14637  12403  9060  6280
# Sudan      2628.0   2471   1945   2442   3580   3159   3515   3658  2949  1867
# Somalia    4451.0   5204   3764   5190   6796   6958   7404   7557  3752  2024
# Kenya      7762.0   7043   6123   5884   5602   6274   6957   7190  7052  4026
# Uganda     1239.0   1340   1350   1409   1664   1649   1898   2412  2560  1802
# Rwanda      520.0    592    540    555    732   1357   1394   1620  1509  1084
# Tanzania   1427.0   1516    837    774    799    788   1415   3186  3142  2312
# Djibouti     56.0    106     90    190    370    281    222    281   151    84

# %%
df_EastAfrica = df.loc[['Eritrea', 'Ethiopia', 'Sudan','Somalia','Kenya',
                'Uganda','Rwanda','Tanzania','Djibouti'], years].transpose()
df_EastAfrica.head()
# Out:
# country  Eritrea  Ethiopia   Sudan  Somalia   Kenya  Uganda  Rwanda  Tanzania  \
# 2011      2102.0   13793.0  2628.0   4451.0  7762.0  1239.0   520.0    1427.0
# 2012      2643.0   14544.0  2471.0   5204.0  7043.0  1340.0   592.0    1516.0
# 2013      2138.0   13097.0  1945.0   3764.0  6123.0  1350.0   540.0     837.0
# 2014      2002.0   12300.0  2442.0   5190.0  5884.0  1409.0   555.0     774.0
# 2015      2220.0   11394.0  3580.0   6796.0  5602.0  1664.0   732.0     799.0
#
# country  Djibouti
# 2011         56.0
# 2012        106.0
# 2013         90.0
# 2014        190.0
# 2015        370.0

# %%
count, bin_edges = np.histogram(df_EastAfrica, 15)

df_EastAfrica.plot(kind ='hist', 
          figsize=(10, 6),
          bins=15,
          alpha=0.6,
          stacked=True,
          xticks=bin_edges,
         )

plt.title('Immigration from East Africa from 2011 - 2020')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# # Bar Chart
# Top 15 Conuntries Contributing to the Immigration to US between 2011 - 2020

# %%
df.sort_values(by='TOTAL', ascending=True, inplace=True)

df_top15 = df['TOTAL'].tail(15)
df_top15
# Out:
# country
# Bangladesh             145307
# Iraq                   147552
# Pakistan               157124
# Colombia               186129
# Haiti                  190880
# Jamaica                196552
# South Korea            197791
# El Salvador            214390
# Vietnam                333900
# Cuba                   468604
# Dominican Republic     481183
# Philippines            496361
# India                  631689
# China                  713527
# Mexico                1480901
# Name: TOTAL, dtype: int64

# %%
df_top15.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Immigrants')
plt.title('Top 15 Conuntries Contributing to the Immigration to US between 2011 - 2020')

for index, value in enumerate(df_top15): 
      label = format(int(value), ',')
plt.annotate(label, xy=(value - 120000, index - 0.10), color='white')

plt.show()

# %% [markdown]
# # Pie Chart

# %%
df.head()
# Out:
#                        TOTAL  2020  2019  2018  2017  2016  2015  2014  2013  \
# country
# Maldives                  64     4     8     4     5    11     8    13     5
# Comoros                   65     4    10     8     4     4     5     9     3
# Sao Tome and Principe     85     4    12     9    10    12     6     5     6
# Seychelles                88     4     6     6    10    16    11     7     6
# Monaco                    90     8     7    13    14    11    10     8     8
#
#                        2012  2011 continnet
# country
# Maldives                  3   3.0      Asia
# Comoros                  10   8.0    Africa
# Sao Tome and Principe    12   9.0    Africa
# Seychelles                7  15.0    Africa
# Monaco                    5   6.0    Europe

# %%
df.rename(columns={'continnet':'Continent'}, 
                    inplace=True)
df.head()
# Out:
#                        TOTAL  2020  2019  2018  2017  2016  2015  2014  2013  \
# country
# Maldives                  64     4     8     4     5    11     8    13     5
# Comoros                   65     4    10     8     4     4     5     9     3
# Sao Tome and Principe     85     4    12     9    10    12     6     5     6
# Seychelles                88     4     6     6    10    16    11     7     6
# Monaco                    90     8     7    13    14    11    10     8     8
#
#                        2012  2011 Continent
# country
# Maldives                  3   3.0      Asia
# Comoros                  10   8.0    Africa
# Sao Tome and Principe    12   9.0    Africa
# Seychelles                7  15.0    Africa
# Monaco                    5   6.0    Europe

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') 

# check for latest version of Matplotlib
print('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.5.3

# %%
df_continents = df.groupby('Continent', axis=0).sum()

print(type(df.groupby('Continent', axis=0)))

df_continents.head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#              TOTAL    2020    2019    2018    2017    2016    2015    2014  \
# Continent
# Africa     1024354   75652  109341  113806  116206  111183  100159   97256
# Asia       3894043  265168  354834  384022  406662  443924  402001  415081
# Australia    49735    3961    5316    4605    5027    5537    5365    5063
# Caribbean  1413292   72855  138005  182338  174489  182059  146650  133834
# Europe      848924   70062   89453   82418   86831   95951   87571   84774
#
#              2013    2012      2011
# Continent
# Africa      96631  105554   98566.0
# Asia       383765  408085  430501.0
# Australia    5226    4698    4937.0
# Caribbean  122206  127317  133539.0
# Europe      87333   82241   82355.0

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink', 'silver']
explode_list = [0, 0, 0.1, 0, 0,0,0]

df_continents['TOTAL'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,        
                            pctdistance=1.12,    
                            colors=colors_list,  
                            explode=explode_list 
                            )

plt.title('Immigration to US by Continent [2011 - 2020]', y=1.12) 
plt.axis('equal') 
plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()

# %% [markdown]
# # Scatter Plot

# %%
df_total = pd.DataFrame(df[years].sum(axis=0))

df_total.index = map(int, df_total.index)

df_total.reset_index(inplace = True)
df_total.columns = ['year', 'Total']

df_total.head()
# Out:
#    year      Total
# 0  2011  1036289.0
# 1  2012  1007662.0
# 2  2013   969452.0
# 3  2014  1000210.0
# 4  2015  1033518.0

# %%
x = df_total['year']     
y = df_total['Total']     
fit = np.polyfit(x, y, deg=1)

fit
# Out:
# array([-1.16578545e+04,  2.45084852e+07])

# %%
df_total.plot(kind='scatter', x='year', y='Total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to US from 2011 - 2020')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')


plt.plot(x, fit[0] * x + fit[1], color='red') 
plt.annotate('y={0:.0f} x + {1:.0f}'.format(fit[0], fit[1]), xy=(2000, 150000))

plt.show()

# print out the line of best fit
'No. Immigrants = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1])
# Out:
# 'No. Immigrants = -11658 * Year + 24508485'

# %% [markdown]
# # Bubble Plots

# %%
# transposed dataframe
df_transpose = df[years].transpose()

df_transpose.index = map(int, df_transpose.index)
df_transpose.index.name = 'Year'

df_transpose.reset_index(inplace=True)
df_transpose.head()
# Out:
# country  Year  Maldives  Comoros  Sao Tome and Principe  Seychelles  Monaco  \
# 0        2011       3.0      8.0                    9.0        15.0     6.0
# 1        2012       3.0     10.0                   12.0         7.0     5.0
# 2        2013       5.0      3.0                    6.0         6.0     8.0
# 3        2014      13.0      9.0                    5.0         7.0     8.0
# 4        2015       8.0      5.0                    6.0        11.0    10.0
#
# country  Micronesia  Palau  French Polynesia  Lesotho  ...  Jamaica  \
# 0               9.0    7.0              21.0     25.0  ...  19662.0
# 1              13.0   10.0              30.0     17.0  ...  20705.0
# 2               4.0   16.0               0.0     20.0  ...  19400.0
# 3               5.0   12.0              24.0     13.0  ...  19026.0
# 4               6.0   15.0              14.0     23.0  ...  17642.0
#
# country  South Korea  El Salvador  Vietnam     Cuba  Dominican Republic  \
# ...

# %%
# normalize Eritrea data
norm_Eritrea = (df_transpose['Eritrea'] - df_transpose['Eritrea'].min()) / (df_transpose['Eritrea'].max() - df_transpose['Eritrea'].min())

# normalize Ethiopia data
norm_Ethiopia = (df_transpose['Ethiopia'] - df_transpose['Ethiopia'].min()) / (df_transpose['Ethiopia'].max() - df_transpose['Ethiopia'].min())

# %%
# Eritrea
ax0 = df_transpose.plot(kind='scatter',
                    x='Year',
                    y='Eritrea',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s=norm_Eritrea * 2000 + 10, 
                    xlim=(2008, 2022)
                    )

# Ethiopia
ax1 = df_transpose.plot(kind='scatter',
                    x='Year',
                    y='Ethiopia',
                    alpha=0.5,
                    color="blue",
                    s=norm_Ethiopia * 2000 + 10,
                    ax=ax0
                    )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Eritrea and Ethiopia from 2011 to 2020')
ax0.legend(['Eritrea', 'Ethiopia'], loc='upper left', fontsize='x-large')
